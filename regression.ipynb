# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np

import sklearn
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from scipy.stats import ttest_ind, norm, zscore

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

data, target = make_regression(n_samples=100, n_features=2, noise=10, random_state=42)

df = pd.DataFrame(data, columns=["Feature 1", "Feature 2"])
df["target"] = target

fig, axs = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
axs[0].scatter(df["Feature 1"], y)
axs[1].scatter(df["Feature 2"], y)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state = 0)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

m = model.coef_[0]
b = model.intercept_

# %%
plt.scatter(df["Feature 1"], y, label='Data')
plt.plot(df["Feature 1"], m*df["Feature 1"] + b, color='red', alpha=0.3, label='Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %% [markdown]
# ## Loading Datasets

# %%
diabetes = datasets.load_diabetes()

diabetes
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
df.sample(10)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 36   0.012648 -0.044642  0.022895  0.052858  0.008063 -0.028558  0.037595
# 193  0.009016  0.050680 -0.005128 -0.064199  0.069981  0.083863 -0.039719
# 275 -0.005515  0.050680 -0.011595  0.011544 -0.022208 -0.015406 -0.021311
# 49  -0.041840  0.050680  0.014272 -0.005670 -0.012577  0.006202 -0.072854
# 198 -0.052738 -0.044642  0.054152 -0.026328 -0.055231 -0.033881 -0.013948
# 434  0.016281 -0.044642  0.001339  0.008101  0.005311  0.010899  0.030232
# 145 -0.041840 -0.044642  0.128521  0.063187 -0.033216 -0.032629  0.011824
# 80   0.070769 -0.044642  0.012117  0.042529  0.071357  0.053487  0.052322
# 78   0.005383 -0.044642 -0.057941 -0.022885 -0.067615 -0.068328 -0.054446
# 420  0.023546 -0.044642 -0.036385  0.000079  0.001183  0.034698 -0.043401
#
#            s4        s5        s6
# 36  -0.039493  0.054720 -0.025930
# 193  0.071210  0.039542  0.019633
# 275 -0.002592  0.011011  0.069338
# ...

# %% [markdown]
# ## Data visualization

# %% [markdown]
# ## Data analytics
