# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sklearn
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data, target = datasets.make_regression(n_samples=100, n_features=2, noise=10, random_state=42)

df = pd.DataFrame(data, columns=["Feature 1", "Feature 2"])
df["target"] = target

fig, axs = plt.subplots(2)
axs[0].scatter(df["Feature 1"], y)
axs[1].scatter(df["Feature 2"], y)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state = 0)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

m = model.coef_[0]
b = model.intercept_

# %%
feature1 = df["Feature 1"]
feature2 = df["Feature 2"]
target = df["target"]

# %%
plt.scatter(feature1, target, label='Data')
plt.plot(feature1, m*feature1 + b, color='red', alpha=0.3, label='Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression for feature 1')
plt.legend()
plt.show()

# %%
plt.scatter(feature2, y, label='Data')
plt.plot(feature1, m*feature1 + b, color='red', alpha=0.3, label='Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression for feature 2')
plt.legend()
plt.show()

# %%
plt.scatter(feature2, target, label='Feature 2')
plt.scatter(feature1, target, label='Feature 1')
plt.title("data map for multiple regression")
plt.legend()
plt.show()
